# %% [markdown]
# <a href="https://colab.research.google.com/github/wetjie/Project_BTPR3203_2026B_Group5/blob/main/Project_BTPR3203_2026B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from main import main
main()
# Out:
# ...
# BTPR3203 GROUP PROJECT
# Graduate Underemployment in Malaysia
# ...
#
# Running RQ1...
# ...
# 1. DATA LOADING AND PREPARATION
# ...
# Existing DOSM datasets found. Loading from data folder...
#
# Missing values check (age): {'date': 0, 'variable': 0, 'age': 0, 'sru': 0}
# Missing values check (sex): {'date': 0, 'variable': 0, 'sex': 0, 'sru': 0}
#
# Age series shape after cleaning: (350, 4)
# Sex series shape after cleaning: (210, 4)
# Date range: 2017-01-01 to 2025-07-01
#
# ...
# 2. EXPLORATORY DATA ANALYSIS
# ...
#
# --- Overall number of skill-related underemployed ('000) ---
# count      35.0
# mean     1705.6
# std       251.4
# min      1182.9
# 25%      1453.6
# 50%      1838.3
# 75%      1917.7
# max      1961.5
# Name: value, dtype: float64
#
# --- Overall rate (%) ---
# count    35.00
# mean     35.39
# std       2.18
# min      29.90
# 25%      33.30
# 50%      36.20
# 75%      37.35
# max      37.90
# Name: value, dtype: float64
#
# --- Age group distribution (latest quarter) ---
#     age  value
# ...
